# %%
#Loading Required Libraries
from keras.models import Model
from keras.layers import Dense
from keras.layers import Flatten

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
import zipfile
import os.path
from os import path

# %%
#Loading Dataset from zip file located in google drive
if not path.exists("intel-image-classification.zip"):
  # !gdown https://drive.google.com/uc?id=1a2zXwkvQaIJLDzUud2WCRNdpQChL0w0K

if not path.exists("dataset"):
  with zipfile.ZipFile('/content/intel-image-classification.zip', 'r') as zip_ref:
    zip_ref.extractall('dataset/')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1a2zXwkvQaIJLDzUud2WCRNdpQChL0w0K
# To: /content/intel-image-classification.zip
# 362MB [00:02, 172MB/s]

# %%
train_data_path = "./dataset/seg_train/"
test_data_path = "./dataset/seg_test/"
#pred_data_path = "./dataset/seg_pred/"

# %%
#Applying augmentation and normalizing dataset.
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

# %%
#flow from directory will load data from directory. It will also label the data with OH label.
train_generator = train_datagen.flow_from_directory(
    train_data_path,
    target_size=(150, 150),
    color_mode="rgb",
    batch_size=32,
    class_mode="categorical",
    shuffle=True
)
# Out:
# Found 14034 images belonging to 6 classes.

# %%
import numpy as np

# %%
# visualize some images
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
valid_datagen = ImageDataGenerator(rescale=1./255)

# %%
#Validation data will load with shuffle enabled without augmentation. Also OHL will done for dataset.
valid_generator = valid_datagen.flow_from_directory(
    test_data_path,
    target_size=(150, 150),
    color_mode="rgb",
    batch_size=32,
    class_mode="categorical",
    shuffle=True
)
# Out:
# Found 3000 images belonging to 6 classes.

# %%
#Loading pre trained CNN model.
from keras.applications.vgg16 import VGG16

# %%
#The size of input of this model is 150x150x3
model = VGG16(include_top=False, input_shape=(150, 150, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step

# %%
# Freezing Conv layers for so that it can't be trained.
for layer in model.layers:
	layer.trainable = False

# %%
# add new classification layers
flat1 = Flatten()(model.layers[-1].output) # flatten last layer
class1 = Dense(1024, activation='relu')(flat1) # add FC layer on previous layer
output = Dense(6, activation='softmax')(class1) # add softmax layer

# %%
# define the new model
model = Model(inputs=model.inputs, outputs=output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              8389632
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 6150
# =================================================================
# Total params: 23,110,470
# Trainable params: 8,395,782
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
#optimizer
from keras.optimizers import SGD
sgd = SGD(lr=0.001, decay=0.0, momentum=.9)
model.compile(loss='categorical_crossentropy', 
              optimizer=sgd,
              metrics=['accuracy'])

# %%
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
HH = model.fit_generator(train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=50
)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 438/438 [==============================] - 98s 206ms/step - loss: 0.8311 - accuracy: 0.6889 - val_loss: 0.4169 - val_accuracy: 0.8444
# Epoch 2/50
# 438/438 [==============================] - 93s 211ms/step - loss: 0.4453 - accuracy: 0.8347 - val_loss: 0.3795 - val_accuracy: 0.8575
# Epoch 3/50
# 438/438 [==============================] - 93s 212ms/step - loss: 0.4019 - accuracy: 0.8529 - val_loss: 0.3812 - val_accuracy: 0.8606
# Epoch 4/50
# 438/438 [==============================] - 93s 213ms/step - loss: 0.3807 - accuracy: 0.8577 - val_loss: 0.4294 - val_accuracy: 0.8340
# Epoch 5/50
# 438/438 [==============================] - 93s 213ms/step - loss: 0.3758 - accuracy: 0.8631 - val_loss: 0.4329 - val_accuracy: 0.8390
# Epoch 6/50
# 438/438 [==============================] - 94s 215ms/step - loss: 0.3625 - accuracy: 0.8683 - val_loss: 0.3332 - val_accuracy: 0.8753
# Epoch 7/50
# 438/438 [==============================] - 94s 214ms/step - loss: 0.3454 - accuracy: 0.8756 - val_loss: 0.3829 - val_accuracy: 0.8572
# Epoch 8/50
# 438/438 [==============================] - 94s 215ms/step - loss: 0.3498 - accuracy: 0.8694 - val_loss: 0.3736 - val_accuracy: 0.8619
# Epoch 9/50
# 438/438 [==============================] - 95s 216ms/step - loss: 0.3433 - accuracy: 0.8701 - val_loss: 0.3265 - val_accuracy: 0.8770
# Epoch 10/50
# 438/438 [==============================] - 95s 216ms/step - loss: 0.3202 - accuracy: 0.8842 - val_loss: 0.3483 - val_accuracy: 0.8710
# Epoch 11/50
# 438/438 [==============================] - 95s 216ms/step - loss: 0.2979 - accuracy: 0.8911 - val_loss: 0.3213 - val_accuracy: 0.8774
# Epoch 12/50
# 438/438 [==============================] - 95s 217ms/step - loss: 0.3017 - accuracy: 0.8913 - val_loss: 0.3275 - val_accuracy: 0.8790
# Epoch 13/50
# 438/438 [==============================] - 95s 217ms/step - loss: 0.2886 - accuracy: 0.8970 - val_loss: 0.3099 - val_accuracy: 0.8797
# Epoch 14/50
# 438/438 [==============================] - 90s 206ms/step - loss: 0.2939 - accuracy: 0.8885 - val_loss: 0.3182 - val_accuracy: 0.8784
# Epoch 15/50
# 438/438 [==============================] - 84s 193ms/step - loss: 0.3018 - accuracy: 0.8892 - val_loss: 0.3468 - val_accuracy: 0.8710
# Epoch 16/50
# 438/438 [==============================] - 84s 192ms/step - loss: 0.2802 - accuracy: 0.8953 - val_loss: 0.3051 - val_accuracy: 0.8868
# Epoch 17/50
# 438/438 [==============================] - 84s 191ms/step - loss: 0.2789 - accuracy: 0.9013 - val_loss: 0.3169 - val_accuracy: 0.8794
# Epoch 18/50
# 438/438 [==============================] - 83s 190ms/step - loss: 0.2809 - accuracy: 0.8933 - val_loss: 0.3031 - val_accuracy: 0.8901
# Epoch 19/50
# 438/438 [==============================] - 84s 191ms/step - loss: 0.2767 - accuracy: 0.8985 - val_loss: 0.3103 - val_accuracy: 0.8807
# Epoch 20/50
# 438/438 [==============================] - 84s 191ms/step - loss: 0.2717 - accuracy: 0.8975 - val_loss: 0.3087 - val_accuracy: 0.8821
# Epoch 21/50
# 438/438 [==============================] - 84s 191ms/step - loss: 0.2752 - accuracy: 0.8994 - val_loss: 0.3169 - val_accuracy: 0.8817
# Epoch 22/50
# 438/438 [==============================] - 84s 192ms/step - loss: 0.2696 - accuracy: 0.8953 - val_loss: 0.3654 - val_accuracy: 0.8720
# Epoch 23/50
# 438/438 [==============================] - 84s 192ms/step - loss: 0.2588 - accuracy: 0.9055 - val_loss: 0.3226 - val_accuracy: 0.8797
# Epoch 24/50
# 438/438 [==============================] - 84s 191ms/step - loss: 0.2513 - accuracy: 0.9096 - val_loss: 0.3496 - val_accuracy: 0.8720
# Epoch 25/50
# 438/438 [==============================] - 84s 191ms/step - loss: 0.2523 - accuracy: 0.9095 - val_loss: 0.3164 - val_accuracy: 0.8831
# Epoch 26/50
# 438/438 [==============================] - 84s 191ms/step - loss: 0.2485 - accuracy: 0.9096 - val_loss: 0.3460 - val_accuracy: 0.8686
# Epoch 27/50
# 438/438 [==============================] - 84s 191ms/step - loss: 0.2378 - accuracy: 0.9103 - val_loss: 0.3385 - val_accuracy: 0.8770
# Epoch 28/50
# 438/438 [==============================] - 83s 190ms/step - loss: 0.2377 - accuracy: 0.9136 - val_loss: 0.3321 - val_accuracy: 0.8720
# Epoch 29/50
# 438/438 [==============================] - 83s 190ms/step - loss: 0.2444 - accuracy: 0.9079 - val_loss: 0.2917 - val_accuracy: 0.8884
# Epoch 30/50
# 438/438 [==============================] - 83s 190ms/step - loss: 0.2324 - accuracy: 0.9159 - val_loss: 0.3366 - val_accuracy: 0.8733
# Epoch 31/50
# 438/438 [==============================] - 84s 191ms/step - loss: 0.2364 - accuracy: 0.9105 - val_loss: 0.2988 - val_accuracy: 0.8911
# Epoch 32/50
# 438/438 [==============================] - 84s 191ms/step - loss: 0.2220 - accuracy: 0.9183 - val_loss: 0.3181 - val_accuracy: 0.8810
# Epoch 33/50
# 438/438 [==============================] - 84s 191ms/step - loss: 0.2375 - accuracy: 0.9104 - val_loss: 0.3090 - val_accuracy: 0.8797
# Epoch 34/50
# 438/438 [==============================] - 84s 192ms/step - loss: 0.2193 - accuracy: 0.9207 - val_loss: 0.2868 - val_accuracy: 0.8925
# Epoch 35/50
# 438/438 [==============================] - 83s 190ms/step - loss: 0.2222 - accuracy: 0.9190 - val_loss: 0.3056 - val_accuracy: 0.8871
# Epoch 36/50
# 438/438 [==============================] - 83s 190ms/step - loss: 0.2128 - accuracy: 0.9203 - val_loss: 0.2986 - val_accuracy: 0.8905
# Epoch 37/50
# 438/438 [==============================] - 83s 190ms/step - loss: 0.2107 - accuracy: 0.9229 - val_loss: 0.2978 - val_accuracy: 0.8905
# Epoch 38/50
# 438/438 [==============================] - 84s 191ms/step - loss: 0.2023 - accuracy: 0.9263 - val_loss: 0.2976 - val_accuracy: 0.8911
# Epoch 39/50
# 438/438 [==============================] - 83s 190ms/step - loss: 0.2103 - accuracy: 0.9251 - val_loss: 0.2858 - val_accuracy: 0.8931
# Epoch 40/50
# 438/438 [==============================] - 83s 191ms/step - loss: 0.2103 - accuracy: 0.9238 - val_loss: 0.3270 - val_accuracy: 0.8841
# Epoch 41/50
# 438/438 [==============================] - 83s 190ms/step - loss: 0.2039 - accuracy: 0.9259 - val_loss: 0.3055 - val_accuracy: 0.8854
# Epoch 42/50
# 438/438 [==============================] - 84s 191ms/step - loss: 0.2217 - accuracy: 0.9160 - val_loss: 0.2999 - val_accuracy: 0.8901
# Epoch 43/50
# 438/438 [==============================] - 83s 190ms/step - loss: 0.1930 - accuracy: 0.9321 - val_loss: 0.2861 - val_accuracy: 0.8938
# Epoch 44/50
# 438/438 [==============================] - 83s 190ms/step - loss: 0.1988 - accuracy: 0.9257 - val_loss: 0.3230 - val_accuracy: 0.8807
# Epoch 45/50
# 438/438 [==============================] - 83s 190ms/step - loss: 0.1957 - accuracy: 0.9273 - val_loss: 0.3066 - val_accuracy: 0.8854
# Epoch 46/50
# 438/438 [==============================] - 83s 190ms/step - loss: 0.1880 - accuracy: 0.9292 - val_loss: 0.3020 - val_accuracy: 0.8942
# Epoch 47/50
# 438/438 [==============================] - 83s 190ms/step - loss: 0.1807 - accuracy: 0.9344 - val_loss: 0.3067 - val_accuracy: 0.8874
# Epoch 48/50
# 438/438 [==============================] - 83s 190ms/step - loss: 0.1930 - accuracy: 0.9294 - val_loss: 0.3112 - val_accuracy: 0.8864
# Epoch 49/50
# 438/438 [==============================] - 83s 190ms/step - loss: 0.1882 - accuracy: 0.9284 - val_loss: 0.3645 - val_accuracy: 0.8683
# Epoch 50/50
# 438/438 [==============================] - 83s 189ms/step - loss: 0.1760 - accuracy: 0.9352 - val_loss: 0.2991 - val_accuracy: 0.8901

# %%
ls drive/MyDrive/Colab\ Notebooks/CV/Assignment3/Working_Codes/
# Out:
#  1wXvIK_pCqgrBho2UJYdrUh0e5drSdeEG   VGG16_with_Constant_lr.ipynb
#  seg_pred/                           VGG16_with_Time-Based_Decay.ipynb
#  TesT_Bench_1.ipynb                  vgg_transfer_trained_50epoch.h5
#  Test_Data.zip                      'vgg_transfer_trained(false)_50epoch.h5'
#  VGG16_TASK1.ipynb                   view
#  vgg16_Time-Based_Decay_50epoch.h5

# %%
# save the model's trained weights
model.save_weights('drive/MyDrive/Colab Notebooks/CV/Assignment3/Working_Codes/VGG16_with_Constant_lr_50epoch.h5')

# %%
'''LEARNING CURVE'''

import matplotlib.pyplot as plt
N = np.arange(0, 50)
plt.style.use('ggplot')
plt.figure()
plt.plot(N, HH.history['loss'], label='train_loss')
plt.plot(N, HH.history['val_loss'], label='val_loss')
plt.plot(N, HH.history['accuracy'], label='train_accuracy')
plt.plot(N, HH.history['val_accuracy'], label='val_accuracy')
plt.title('Training loss and accuracy')
plt.xlabel('Epoch #')
plt.ylabel('Loss/Accuracy')
plt.legend()
plt.show()

# %%
ls
# Out:
# dataset/  drive/  intel-image-classification.zip  sample_data/

# %%
# necessary imports
import os
import cv2
from imutils import paths
from sklearn.preprocessing import LabelBinarizer
from tqdm import tqdm

# %%
# A function to load data from a given directory
def load_data(data_dir):
  data = []
  labels = []
  class_dirs = os.listdir(data_dir)
  
  for direc in class_dirs:
    class_dir = os.path.join(data_dir, direc)
    for imagepath in tqdm(list(paths.list_images(class_dir))):
      image = cv2.imread(imagepath)
      image = cv2.resize(image, (150, 150))  # incase images not of same size
      data.append(image)
      labels.append(direc)
  # normalizing and converting to numpy array format
  data = np.array(data, dtype='float')/255.0
  labels = np.array(labels)
  return data, labels

# %%
pred_data_path = "drive/MyDrive/Colab Notebooks/CV/Assignment3/Data_Set/seg_pred/seg_pred/"

# %%
print('loading test images')
X_test, y_test = load_data(pred_data_path)
# Out:
# loading test images
# 100%|██████████| 1330/1330 [09:35<00:00,  2.31it/s]
# 100%|██████████| 1128/1128 [08:32<00:00,  2.20it/s]
# 100%|██████████| 1166/1166 [08:53<00:00,  2.19it/s]
# 100%|██████████| 1297/1297 [09:40<00:00,  2.23it/s]
# 100%|██████████| 1144/1144 [08:39<00:00,  2.20it/s]
# 100%|██████████| 1236/1236 [11:42<00:00,  1.76it/s]

# %%
lb = LabelBinarizer()
y_test = lb.fit_transform(y_test)

# %%
y_test[0]
# Out:
# array([0, 0, 1, 0, 0, 0])

# %%
score = model.evaluate(X_test, y_test, batch_size=32)
print('Test Loss = ', score[0])
print('Test Accuracy = ', score[1])
# Out:
# 229/229 [==============================] - 16s 71ms/step - loss: 0.2371 - accuracy: 0.9107
# Test Loss =  0.23705574870109558
# Test Accuracy =  0.9106971621513367

# %%
'''CONFUSION MATRIX'''
# Making prediction
y_pred = model.predict(X_test)
y_true = np.argmax(y_test, axis=-1)

# Plotting the confusion matrix
from sklearn.metrics import confusion_matrix
confusion_mtx = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

# %%
confusion_mtx
# Out:
# array([[1069,    1,    1,    0,   10,   63],
#        [   5, 1134,    4,    4,    9,   10],
#        [   7,    1, 1072,  193,   53,    4],
#        [   3,    4,   82, 1130,   72,    6],
#        [   2,    3,   17,   51, 1043,   12],
#        [  26,    2,    5,    0,    2, 1201]])
