# %%
#Loading Required Libraries
from keras.models import Model
from keras.layers import Dense
from keras.layers import Flatten

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
import zipfile
import os.path
from os import path

# %%
#Loading Dataset from zip file located in google drive
if not path.exists("intel-image-classification.zip"):
  # !gdown https://drive.google.com/uc?id=1a2zXwkvQaIJLDzUud2WCRNdpQChL0w0K

if not path.exists("dataset"):
  with zipfile.ZipFile('/content/intel-image-classification.zip', 'r') as zip_ref:
    zip_ref.extractall('dataset/')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1a2zXwkvQaIJLDzUud2WCRNdpQChL0w0K
# To: /content/intel-image-classification.zip
# 362MB [00:03, 94.1MB/s]

# %%
train_data_path = "./dataset/seg_train/"
test_data_path = "./dataset/seg_test/"
#pred_data_path = "./dataset/seg_pred/"

# %%
#No augmentation is applied but normalizing dataset.
train_datagen = ImageDataGenerator(rescale=1./255)

# %%
#flow from directory will load data from directory. It will also label the data with OH label.
train_generator = train_datagen.flow_from_directory(
    train_data_path,
    target_size=(150, 150),
    color_mode="rgb",
    batch_size=32,
    class_mode="categorical",
    shuffle=True
)
# Out:
# Found 14034 images belonging to 6 classes.

# %%
import numpy as np

# %%
# visualize some images
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
valid_datagen = ImageDataGenerator(rescale=1./255)

# %%
#Validation data will load with shuffle enabled without augmentation. Also OHL will done for dataset.
valid_generator = valid_datagen.flow_from_directory(
    test_data_path,
    target_size=(150, 150),
    color_mode="rgb",
    batch_size=32,
    class_mode="categorical",
    shuffle=True
)
# Out:
# Found 3000 images belonging to 6 classes.

# %%
#Loading pre trained CNN model.
from keras.applications.vgg16 import VGG16

# %%
#The size of input of this model is 150x150x3
model = VGG16(include_top=False, input_shape=(150, 150, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step

# %%
# Freezing Conv layers for so that it can't be trained.
for layer in model.layers:
	layer.trainable = False

# %%
# add new classification layers
flat1 = Flatten()(model.layers[-1].output) # flatten last layer
class1 = Dense(1024, activation='relu')(flat1) # add FC layer on previous layer
output = Dense(6, activation='softmax')(class1) # add softmax layer

# %%
# define the new model
model = Model(inputs=model.inputs, outputs=output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              8389632
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 6150
# =================================================================
# Total params: 23,110,470
# Trainable params: 8,395,782
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
#optimizer
from keras.optimizers import SGD
sgd = SGD(lr=0.001, decay=0.0, momentum=.9)
model.compile(loss='categorical_crossentropy', 
              optimizer=sgd,
              metrics=['accuracy'])

# %%
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size
HH = model.fit_generator(train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=50
)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 438/438 [==============================] - 44s 82ms/step - loss: 0.8263 - accuracy: 0.6882 - val_loss: 0.4191 - val_accuracy: 0.8424
# Epoch 2/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.4075 - accuracy: 0.8522 - val_loss: 0.4341 - val_accuracy: 0.8320
# Epoch 3/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.3634 - accuracy: 0.8636 - val_loss: 0.4242 - val_accuracy: 0.8306
# Epoch 4/50
# 438/438 [==============================] - 37s 83ms/step - loss: 0.3323 - accuracy: 0.8785 - val_loss: 0.3899 - val_accuracy: 0.8474
# Epoch 5/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.3051 - accuracy: 0.8894 - val_loss: 0.3510 - val_accuracy: 0.8733
# Epoch 6/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.3024 - accuracy: 0.8945 - val_loss: 0.3621 - val_accuracy: 0.8609
# Epoch 7/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.2746 - accuracy: 0.9034 - val_loss: 0.3300 - val_accuracy: 0.8780
# Epoch 8/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.2697 - accuracy: 0.9016 - val_loss: 0.3349 - val_accuracy: 0.8760
# Epoch 9/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.2494 - accuracy: 0.9112 - val_loss: 0.3571 - val_accuracy: 0.8595
# Epoch 10/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.2453 - accuracy: 0.9114 - val_loss: 0.3124 - val_accuracy: 0.8847
# Epoch 11/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.2231 - accuracy: 0.9208 - val_loss: 0.3198 - val_accuracy: 0.8821
# Epoch 12/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.2191 - accuracy: 0.9213 - val_loss: 0.3193 - val_accuracy: 0.8834
# Epoch 13/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.2169 - accuracy: 0.9223 - val_loss: 0.3997 - val_accuracy: 0.8522
# Epoch 14/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.2121 - accuracy: 0.9267 - val_loss: 0.3395 - val_accuracy: 0.8807
# Epoch 15/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.2024 - accuracy: 0.9312 - val_loss: 0.3011 - val_accuracy: 0.8871
# Epoch 16/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.1832 - accuracy: 0.9373 - val_loss: 0.3114 - val_accuracy: 0.8837
# Epoch 17/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.1866 - accuracy: 0.9389 - val_loss: 0.3382 - val_accuracy: 0.8763
# Epoch 18/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.1799 - accuracy: 0.9391 - val_loss: 0.3357 - val_accuracy: 0.8784
# Epoch 19/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.1632 - accuracy: 0.9435 - val_loss: 0.3153 - val_accuracy: 0.8821
# Epoch 20/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.1555 - accuracy: 0.9460 - val_loss: 0.3563 - val_accuracy: 0.8750
# Epoch 21/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.1513 - accuracy: 0.9514 - val_loss: 0.3208 - val_accuracy: 0.8817
# Epoch 22/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.1617 - accuracy: 0.9471 - val_loss: 0.3576 - val_accuracy: 0.8774
# Epoch 23/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.1488 - accuracy: 0.9479 - val_loss: 0.3185 - val_accuracy: 0.8868
# Epoch 24/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.1341 - accuracy: 0.9560 - val_loss: 0.3310 - val_accuracy: 0.8777
# Epoch 25/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.1297 - accuracy: 0.9589 - val_loss: 0.3113 - val_accuracy: 0.8841
# Epoch 26/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.1227 - accuracy: 0.9609 - val_loss: 0.3242 - val_accuracy: 0.8824
# Epoch 27/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.1277 - accuracy: 0.9570 - val_loss: 0.3475 - val_accuracy: 0.8774
# Epoch 28/50
# 438/438 [==============================] - 37s 83ms/step - loss: 0.1183 - accuracy: 0.9596 - val_loss: 0.3252 - val_accuracy: 0.8861
# Epoch 29/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.1128 - accuracy: 0.9629 - val_loss: 0.3396 - val_accuracy: 0.8787
# Epoch 30/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.1112 - accuracy: 0.9657 - val_loss: 0.3376 - val_accuracy: 0.8861
# Epoch 31/50
# 438/438 [==============================] - 37s 83ms/step - loss: 0.1021 - accuracy: 0.9676 - val_loss: 0.3349 - val_accuracy: 0.8827
# Epoch 32/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.0964 - accuracy: 0.9712 - val_loss: 0.3557 - val_accuracy: 0.8740
# Epoch 33/50
# 438/438 [==============================] - 37s 83ms/step - loss: 0.0898 - accuracy: 0.9749 - val_loss: 0.3389 - val_accuracy: 0.8864
# Epoch 34/50
# 438/438 [==============================] - 37s 83ms/step - loss: 0.0894 - accuracy: 0.9726 - val_loss: 0.3385 - val_accuracy: 0.8851
# Epoch 35/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.0803 - accuracy: 0.9768 - val_loss: 0.3374 - val_accuracy: 0.8874
# Epoch 36/50
# 438/438 [==============================] - 37s 83ms/step - loss: 0.0795 - accuracy: 0.9780 - val_loss: 0.3367 - val_accuracy: 0.8908
# Epoch 37/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.0824 - accuracy: 0.9745 - val_loss: 0.3442 - val_accuracy: 0.8868
# Epoch 38/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.0803 - accuracy: 0.9768 - val_loss: 0.3490 - val_accuracy: 0.8861
# Epoch 39/50
# 438/438 [==============================] - 37s 83ms/step - loss: 0.0724 - accuracy: 0.9815 - val_loss: 0.3520 - val_accuracy: 0.8834
# Epoch 40/50
# 438/438 [==============================] - 37s 83ms/step - loss: 0.0690 - accuracy: 0.9789 - val_loss: 0.3591 - val_accuracy: 0.8841
# Epoch 41/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.0660 - accuracy: 0.9825 - val_loss: 0.3865 - val_accuracy: 0.8831
# Epoch 42/50
# 438/438 [==============================] - 37s 83ms/step - loss: 0.0632 - accuracy: 0.9837 - val_loss: 0.3544 - val_accuracy: 0.8921
# Epoch 43/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.0619 - accuracy: 0.9843 - val_loss: 0.4018 - val_accuracy: 0.8726
# Epoch 44/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.0598 - accuracy: 0.9859 - val_loss: 0.3540 - val_accuracy: 0.8851
# Epoch 45/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.0520 - accuracy: 0.9884 - val_loss: 0.3757 - val_accuracy: 0.8858
# Epoch 46/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.0484 - accuracy: 0.9894 - val_loss: 0.3987 - val_accuracy: 0.8753
# Epoch 47/50
# 438/438 [==============================] - 37s 83ms/step - loss: 0.0539 - accuracy: 0.9869 - val_loss: 0.3816 - val_accuracy: 0.8824
# Epoch 48/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.0512 - accuracy: 0.9877 - val_loss: 0.3742 - val_accuracy: 0.8817
# Epoch 49/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.0485 - accuracy: 0.9887 - val_loss: 0.3818 - val_accuracy: 0.8824
# Epoch 50/50
# 438/438 [==============================] - 37s 84ms/step - loss: 0.0408 - accuracy: 0.9918 - val_loss: 0.3887 - val_accuracy: 0.8847

# %%
ls drive/MyDrive/Colab\ Notebooks/CV/Assignment3/Working_Codes/
# Out:
#  1wXvIK_pCqgrBho2UJYdrUh0e5drSdeEG
# 'No Augmentation VGG16_with_Constant_lr.ipynb'
#  seg_pred/
#  TesT_Bench_1.ipynb
#  Test_Data.zip
#  VGG16_TASK1.ipynb
#  vgg16_Time-Based_Decay_50epoch.h5
#  VGG16_with_Constant_lr_50epoch.h5
#  VGG16_with_Constant_lr.ipynb
#  VGG16_with_EXP_lr_Decay.ipynb
#  VGG16_with_Time-Based_Decay.ipynb
#  vgg_transfer_trained_50epoch.h5
# 'vgg_transfer_trained(false)_50epoch.h5'
#  view

# %%
# save the model's trained weights
model.save_weights('drive/MyDrive/Colab Notebooks/CV/Assignment3/Working_Codes/No_Augmentation_VGG16_with_Constant_lr_50epoch.h5')

# %%
'''LEARNING CURVE'''

import matplotlib.pyplot as plt
N = np.arange(0, 50)
plt.style.use('ggplot')
plt.figure()
plt.plot(N, HH.history['loss'], label='train_loss')
plt.plot(N, HH.history['val_loss'], label='val_loss')
plt.plot(N, HH.history['accuracy'], label='train_accuracy')
plt.plot(N, HH.history['val_accuracy'], label='val_accuracy')
plt.title('Training loss and accuracy')
plt.xlabel('Epoch #')
plt.ylabel('Loss/Accuracy')
plt.legend()
plt.show()

# %%
ls
# Out:
# dataset/  drive/  intel-image-classification.zip  sample_data/

# %%
# necessary imports
import os
import cv2
from imutils import paths
from sklearn.preprocessing import LabelBinarizer
from tqdm import tqdm

# %%
# A function to load data from a given directory
def load_data(data_dir):
  data = []
  labels = []
  class_dirs = os.listdir(data_dir)
  
  for direc in class_dirs:
    class_dir = os.path.join(data_dir, direc)
    for imagepath in tqdm(list(paths.list_images(class_dir))):
      image = cv2.imread(imagepath)
      image = cv2.resize(image, (150, 150))  # incase images not of same size
      data.append(image)
      labels.append(direc)
  # normalizing and converting to numpy array format
  data = np.array(data, dtype='float')/255.0
  labels = np.array(labels)
  return data, labels

# %%
pred_data_path = "drive/MyDrive/Colab Notebooks/CV/Assignment3/Data_Set/seg_pred/seg_pred/"

# %%
print('loading test images')
X_test, y_test = load_data(pred_data_path)
# Out:
# loading test images
# 100%|██████████| 1330/1330 [12:31<00:00,  1.77it/s]
# 100%|██████████| 1128/1128 [07:21<00:00,  2.55it/s]
# 100%|██████████| 1166/1166 [07:22<00:00,  2.63it/s]
# 100%|██████████| 1297/1297 [08:20<00:00,  2.59it/s]
# 100%|██████████| 1144/1144 [07:12<00:00,  2.65it/s]
# 100%|██████████| 1236/1236 [07:53<00:00,  2.61it/s]

# %%
lb = LabelBinarizer()
y_test = lb.fit_transform(y_test)

# %%
y_test[0]
# Out:
# array([0, 0, 1, 0, 0, 0])

# %%
score = model.evaluate(X_test, y_test, batch_size=32)
print('Test Loss = ', score[0])
print('Test Accuracy = ', score[1])
# Out:
# 229/229 [==============================] - 15s 63ms/step - loss: 0.3417 - accuracy: 0.8869
# Test Loss =  0.34174638986587524
# Test Accuracy =  0.8868648409843445

# %%
'''CONFUSION MATRIX'''
# Making prediction
y_pred = model.predict(X_test)
y_true = np.argmax(y_test, axis=-1)

# Plotting the confusion matrix
from sklearn.metrics import confusion_matrix
confusion_mtx = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

# %%
confusion_mtx
# Out:
# array([[1075,    2,    0,    0,    9,   58],
#        [   1, 1151,    3,    0,    9,    2],
#        [   8,   11,  945,  176,  180,   10],
#        [   5,   26,   48,  989,  217,   12],
#        [   2,    3,    5,    8, 1103,    7],
#        [  16,    4,    1,    0,    3, 1212]])
